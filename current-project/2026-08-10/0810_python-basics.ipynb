# %%
print("hellow world")
# Out:
# hellow world

# %%
print("hellow world")
# Out:
# hellow world

# %%
2+2
# Out:
# 4

# %%
50-5*6
# Out:
# 20

# %%
(50-5*6)/4
# Out:
# 5.0

# %%
17/3
# Out:
# 5.666666666666667

# %%
17//3
# Out:
# 5

# %%
17%3
# Out:
# 2

# %%
5 **2
# Out:
# 25

# %%
2**7
# Out:
# 128

# %%
width = 20

# %%
height = 5*9

# %%
area= width* height

# %%
area
# Out:
# 900

# %%
4*3.75-1
# Out:
# 14.0

# %%
tax =12.5/100

# %%
price=100.50

# %%
price*tax
# Out:
# 12.5625

# %%
price +_ #_변수는 이전에 계산한 값 12.5625를 저장
# Out:
# 113.0625

# %%
##변수

# %%
x=5
y="사과"
print(x)
# Out:
# 5

# %%
print(y)
# Out:
# 사과

# %%
x=4

# %%
x="banan"

# %%
print(x)
# Out:
# banan

# %%
x,y,z="오렌지", "바나나","체리"
print(x)
print(y)
print(z)
# Out:
# 오렌지
# 바나나
# 체리

# %%
x="홍길동"
print("my name is"+x)
# Out:
# my name is홍길동

# %%
x="내 이름은"
y=" 4" #문자열과 정수는 결합할 수 없다. 
print(x+y)
# Out:
# 내 이름은 4

# %%
x=int(1)
y=int(2.8)
z=int("3")
print(x,y,z)
# Out:
# 1 2 3

# %%
x=float(1)
y=float(2.8)
z=float("4.2")
print(x,y,z)
# Out:
# 1.0 2.8 4.2

# %%
x=str(1)
y=str(2.8)
z=str("3.0")
print(x,y,z)
# Out:
# 1 2.8 3.0

# %%
z=int("4") #int("4.2")는 안됨
print(z)
z=int(4.2)
print(z)
# Out:
# 4
# 4

# %%
message="""여러 줄에 걸친 문자열은 따옴표 3개로 표시한다. 
지금부터 다음 줄이다.""" #\n없이 그냥 줄바꿔도 됨
print(message)
# Out:
# 여러 줄에 걸친 문자열은 따옴표 3개로 표시한다.
# 지금부터 다음 줄이다.

# %%
message="첫번째 줄 = doesn\'t\n두번째 줄= \"Hello\"" 
print(message)
# Out:
# 첫번째 줄 = doesn't
# 두번째 줄= "Hello"

# %%
#문자열의 반복
line="$" *30
print(line)
# Out:
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$

# %%
#문자열 안에서 변수의 값을 삽입하여 출력 , 반복문 사용시에 사용
age=23
print("제 나이는 %s세 입니다." %age)
# Out:
# 제 나이는 23세 입니다.

# %%
#실습문제1
print("/", "*" *28)
print("*"," " *26, "*")
print("*"," " *6, "이름: 홍 길동"," " *6, "*")
print("*"," " *6, "나이: 20"," " *11, "*")
print("*"," " *6, "주소: 대구광역시"," " *3, "*")
print("*"," " *26, "*")
print("*" *28,"/")
# Out:
# / ****************************
# *                            *
# *        이름: 홍 길동        *
# *        나이: 20             *
# *        주소: 대구광역시     *
# *                            *
# **************************** /

# %%
#실습문제2
a=4.0
bplus=3.5
b=3.0
cplus=2.5
c=2.0

grade=(a+bplus+c)/3.0
print("철수의 평균 성적은", grade,"이다.")
# Out:
# 철수의 평균 성적은 3.1666666666666665 이다.

# %%
#실습문제3
r=3
pie=3.14159

area=pie*r**2
Volume=(4/3)*pie*r**3

print("원의 면적:",area,"\n구의 부피:", Volume)
# Out:
# 원의 면적: 28.27431
# 구의 부피: 113.09723999999999
